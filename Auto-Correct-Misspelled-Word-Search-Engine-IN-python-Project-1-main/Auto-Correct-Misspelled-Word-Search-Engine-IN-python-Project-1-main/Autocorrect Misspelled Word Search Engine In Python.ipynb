# %% [markdown]
# # Import Necessary packages

# %%
import string
import re
import numpy as np
from collections import Counter

# %% [markdown]
# # 1: Reading all words and for this we need vocabulary dictionary

# %%
def read_corpus(filename):
    with open(filename,'r',encoding='utf-8') as file:
        lines = file.readlines()
        
        words = []
        for word in lines:
            words += re.findall(r'\w+',word.lower())
    return words

# invoke this function
corpus = read_corpus(r'big.txt')

# %%
len(corpus)
# Out:
# 222663

# %% [markdown]
# # create our vocabulary for unique words

# %%
vocab = set(corpus)
len(vocab)
# Out:
# 17647

# %% [markdown]
# # To see how many times words appear in our corpus (text)  (test)

# %%
words_count = Counter(corpus)
words_count
# Out:
# Counter({'the': 14703,
#          'of': 6742,
#          'and': 6517,
#          'a': 4799,
#          'to': 4707,
#          'in': 4238,
#          'that': 3081,
#          'it': 2534,
#          'his': 2530,
#          'i': 2120,
#          'he': 1896,
#          'but': 1823,
#          's': 1819,
#          'with': 1769,
#          'as': 1752,
#          'is': 1751,
#          'was': 1646,
#          'for': 1644,
#          'all': 1544,
#          'this': 1439,
#          'at': 1335,
#          'whale': 1230,
#          'by': 1222,
#          'not': 1173,
#          'from': 1104,
#          'on': 1073,
#          'so': 1066,
#          'him': 1065,
#          'be': 1063,
#          'you': 958,
#          'one': 924,
#          'there': 865,
#          'or': 797,
#          'now': 786,
#          'had': 779,
#          'have': 774,
#          'were': 683,
#          'they': 668,
#          'which': 655,
#          'like': 647,
#          'then': 630,
#          'me': 629,
#          'their': 620,
#          'some': 619,
#          'are': 618,
#          'what': 617,
#          'when': 607,
#          'an': 600,
#          'no': 594,
#          'my': 586,
#          'upon': 568,
#          'out': 537,
#          'man': 527,
#          'up': 526,
#          'into': 523,
#          'ship': 519,
#          'ahab': 512,
#          'more': 507,
#          'if': 501,
#          'them': 474,
#          'ye': 472,
#          'we': 469,
#          'sea': 455,
#          'old': 452,
#          'would': 432,
#          'other': 430,
#          'been': 415,
#          'over': 410,
#          'these': 405,
#          'will': 399,
#          'though': 384,
#          'its': 382,
#          'down': 379,
#          'only': 378,
#          'such': 376,
#          'who': 366,
#          'any': 364,
#          'head': 348,
#          'yet': 345,
#          'boat': 334,
#          'time': 334,
#          'long': 332,
#          'her': 332,
#          'captain': 328,
#          'very': 323,
#          'here': 320,
#          'about': 318,
#          'do': 316,
#          'still': 312,
#          'than': 311,
#          'chapter': 308,
#          'great': 307,
#          'those': 307,
#          'said': 305,
#          'before': 301,
#          'two': 296,
#          'must': 293,
#          'has': 293,
#          't': 290,
#          'most': 285,
#          'seemed': 283,
#          'white': 280,
#          'last': 278,
#          'see': 275,
#          'way': 273,
#          'whales': 271,
#          'thou': 271,
#          'after': 270,
#          'again': 263,
#          'stubb': 259,
#          'how': 258,
#          'your': 257,
#          'did': 256,
#          'may': 255,
#          'queequeg': 253,
#          'little': 249,
#          'can': 247,
#          'round': 247,
#          'while': 246,
#          'three': 245,
#          'say': 244,
#          'men': 244,
#          'sperm': 242,
#          'first': 239,
#          'through': 235,
#          'every': 232,
#          'well': 230,
#          'us': 229,
#          'much': 224,
#          'being': 224,
#          'where': 223,
#          'off': 220,
#          'could': 217,
#          'good': 216,
#          'hand': 215,
#          'same': 215,
#          'our': 211,
#          'side': 208,
#          'ever': 206,
#          'never': 206,
#          'own': 205,
#          'look': 205,
#          'himself': 204,
#          'deck': 199,
#          'starbuck': 199,
#          'almost': 197,
#          'even': 193,
#          'go': 193,
#          'water': 190,
#          'thing': 188,
#          'away': 186,
#          'too': 185,
#          'should': 185,
#          'might': 183,
#          'come': 180,
#          'day': 179,
#          'made': 178,
#          'pequod': 177,
#          'world': 176,
#          'life': 175,
#          'sir': 171,
#          'fish': 169,
#          'many': 168,
#          'among': 167,
#          'seen': 165,
#          'far': 165,
#          'without': 164,
#          'back': 161,
#          'line': 160,
#          'let': 158,
#          'oh': 157,
#          'eyes': 156,
#          'nor': 156,
#          'cried': 156,
#          'right': 155,
#          'aye': 154,
#          'god': 153,
#          'part': 153,
#          'know': 153,
#          'night': 152,
#          'sort': 152,
#          'thought': 150,
#          'once': 149,
#          'boats': 147,
#          'air': 143,
#          'crew': 141,
#          'don': 138,
#          'take': 137,
#          'whole': 137,
#          'full': 136,
#          'half': 136,
#          'against': 135,
#          'things': 134,
#          'tell': 134,
#          'thus': 133,
#          'whaling': 132,
#          'thee': 131,
#          'mast': 130,
#          'came': 130,
#          'soon': 130,
#          'small': 130,
#          'each': 129,
#          'hands': 129,
#          'under': 126,
#          'feet': 126,
#          'both': 126,
#          'till': 123,
#          'think': 122,
#          'something': 122,
#          'between': 120,
#          'she': 119,
#          'why': 119,
#          'found': 118,
#          'just': 117,
#          'place': 117,
#          'called': 116,
#          'saw': 116,
#          'towards': 115,
#          'nothing': 115,
#          'make': 115,
#          'another': 115,
#          'poor': 114,
#          'll': 113,
#          'times': 112,
#          'thy': 112,
#          'body': 110,
#          'heard': 110,
#          'along': 110,
#          'flask': 109,
#          'work': 109,
#          'high': 108,
#          'stand': 107,
#          'moment': 105,
#          'sight': 105,
#          'end': 103,
#          'voyage': 103,
#          'sail': 102,
#          'new': 102,
#          'sun': 102,
#          'hold': 99,
#          'does': 98,
#          'strange': 98,
#          'shall': 97,
#          'years': 97,
#          'went': 97,
#          'however': 96,
#          'leviathan': 95,
#          'few': 95,
#          'get': 95,
#          'face': 95,
#          'gutenberg': 94,
#          'nantucket': 94,
#          'also': 93,
#          'because': 93,
#          'dead': 92,
#          'project': 91,
#          'leg': 91,
#          'heart': 91,
#          'whether': 91,
#          'certain': 91,
#          'moby': 90,
#          'dick': 90,
#          'give': 90,
#          'going': 90,
#          'arm': 90,
#          'am': 90,
#          'oil': 90,
#          'stood': 90,
#          'black': 90,
#          'death': 89,
#          'perhaps': 89,
#          'indeed': 89,
#          'true': 88,
#          'iron': 88,
#          'eye': 88,
#          'ships': 88,
#          'cabin': 87,
#          'heads': 87,
#          'whose': 87,
#          'sometimes': 87,
#          'seas': 87,
#          'seems': 87,
#          'matter': 87,
#          'days': 86,
#          'set': 85,
#          'jonah': 85,
#          'seem': 85,
#          'hard': 84,
#          'itself': 84,
#          'wild': 84,
#          'within': 83,
#          'soul': 83,
#          'standing': 82,
#          'tail': 81,
#          'harpooneer': 81,
#          'mind': 81,
#          'sailor': 81,
#          'known': 80,
#          'land': 80,
#          'always': 80,
#          'young': 80,
#          'present': 80,
#          'ocean': 79,
#          'large': 79,
#          'mate': 79,
#          'ere': 79,
#          'light': 79,
#          'length': 78,
#          'word': 77,
#          'instant': 77,
#          'bildad': 77,
#          'least': 76,
#          'open': 76,
#          'fire': 76,
#          'beneath': 76,
#          'enough': 76,
#          'harpoon': 76,
#          'bed': 76,
#          'd': 75,
#          'yes': 75,
#          'four': 74,
#          'board': 74,
#          'morning': 74,
#          'done': 74,
#          'pip': 74,
#          'vast': 73,
#          'living': 73,
#          'cannot': 73,
#          'put': 73,
#          'often': 73,
#          'peleg': 73,
#          'case': 72,
#          'point': 72,
#          'lay': 72,
#          'whalemen': 72,
#          'general': 72,
#          'rather': 72,
#          'keep': 71,
#          'top': 71,
#          'name': 70,
#          'deep': 70,
#          'near': 70,
#          'wind': 70,
#          'looking': 70,
#          'business': 70,
#          'myself': 69,
#          'waters': 69,
#          'therefore': 67,
#          'left': 67,
#          'best': 66,
#          'turned': 66,
#          'lord': 65,
#          'since': 65,
#          'having': 65,
#          'boy': 65,
#          'fast': 64,
#          'works': 64,
#          'together': 64,
#          'hear': 64,
#          'order': 64,
#          'reason': 64,
#          'looked': 64,
#          'lower': 64,
#          'aloft': 63,
#          'king': 63,
#          'mr': 63,
#          'better': 63,
#          'fishery': 63,
#          'chase': 62,
#          'second': 62,
#          'blood': 62,
#          'further': 62,
#          'watch': 61,
#          'spout': 61,
#          'mouth': 61,
#          'turn': 61,
#          'rope': 60,
#          'book': 60,
#          'short': 60,
#          'forth': 60,
#          'live': 60,
#          'st': 60,
#          'gone': 59,
#          'themselves': 59,
#          'fine': 59,
#          'above': 58,
#          'jaw': 58,
#          'dark': 58,
#          'broad': 58,
#          'feel': 57,
#          'indian': 57,
#          'room': 57,
#          'tm': 57,
#          'mark': 56,
#          'find': 56,
#          'close': 56,
#          'harpooneers': 56,
#          'peculiar': 56,
#          'home': 56,
#          'ivory': 56,
#          'next': 56,
#          'tashtego': 56,
#          'try': 55,
#          'devil': 55,
#          'goes': 55,
#          'vessel': 55,
#          'call': 55,
#          'savage': 55,
#          'entire': 55,
#          'less': 54,
#          'grand': 54,
#          'coming': 54,
#          'stern': 54,
#          'run': 54,
#          'main': 54,
#          'green': 54,
#          'fellow': 54,
#          'cook': 54,
#          'craft': 54,
#          'bottom': 54,
#          'curious': 54,
#          'ground': 54,
#          'coffin': 53,
#          'cut': 53,
#          'taking': 53,
#          'turning': 53,
#          'began': 53,
#          'comes': 53,
#          'e': 52,
#          'speak': 52,
#          'forward': 52,
#          'slowly': 52,
#          'sailors': 52,
#          'below': 52,
#          'story': 51,
#          'taken': 51,
#          'bone': 51,
#          'heaven': 51,
#          'sharks': 51,
#          'wide': 51,
#          'thousand': 51,
#          'particular': 51,
#          'rest': 51,
#          'used': 51,
#          'teeth': 50,
#          'view': 50,
#          'carpenter': 50,
#          'besides': 50,
#          'behind': 50,
#          'hundred': 50,
#          'form': 50,
#          'suddenly': 50,
#          'nevertheless': 50,
#          'broken': 50,
#          'use': 49,
#          'english': 49,
#          '1': 49,
#          '_': 49,
#          'monster': 49,
#          'bones': 49,
#          'people': 49,
#          'struck': 49,
#          'took': 49,
#          'common': 49,
#          'bows': 49,
#          'quarter': 48,
#          'waves': 48,
#          'ten': 48,
#          'several': 48,
#          'voice': 48,
#          'stranger': 48,
#          'pull': 48,
#          'lost': 47,
#          'mighty': 47,
#          'told': 47,
#          'kept': 47,
#          'means': 47,
#          'earth': 46,
#          'whatever': 46,
#          'touching': 46,
#          'making': 46,
#          'chance': 46,
#          'whaleman': 46,
#          'straight': 46,
#          'sleep': 46,
#          'else': 46,
#          'says': 46,
#          'fact': 46,
#          'got': 46,
#          'running': 46,
#          'whom': 45,
#          'caught': 45,
#          'sat': 45,
#          'lance': 45,
#          'sure': 45,
#          'especially': 45,
#          'blue': 45,
#          'anything': 45,
#          'door': 45,
#          'mine': 45,
#          'sails': 45,
#          'queer': 44,
#          'somehow': 44,
#          'noble': 44,
#          'o': 44,
#          'bow': 44,
#          'nigh': 44,
#          'house': 44,
#          'five': 44,
#          'hole': 44,
#          'knew': 43,
#          'rolled': 43,
#          'seamen': 43,
#          'pipe': 42,
#          'alone': 42,
#          'mere': 42,
#          'nature': 42,
#          'coast': 42,
#          'purpose': 42,
#          'hours': 42,
#          'passed': 42,
#          'sharp': 42,
#          'ready': 42,
#          'em': 42,
#          'concerning': 42,
#          'course': 42,
#          'sudden': 42,
#          'creature': 42,
#          'wondrous': 42,
#          'surface': 42,
#          'hat': 41,
#          'clear': 41,
#          'art': 41,
#          'calm': 41,
#          'either': 41,
#          'quite': 41,
#          'parts': 41,
#          'help': 41,
#          'felt': 41,
#          'sound': 41,
#          'brow': 41,
#          'others': 40,
#          'wake': 40,
#          'mortal': 40,
#          'mean': 40,
#          'easy': 40,
#          'quick': 40,
#          'cape': 40,
#          'red': 40,
#          'hour': 40,
#          'plain': 40,
#          'saying': 40,
#          'mates': 40,
#          'makes': 40,
#          'gold': 40,
#          'steelkilt': 40,
#          'plainly': 39,
#          'distance': 39,
#          'object': 39,
#          'mass': 39,
#          'single': 39,
#          'various': 39,
#          'low': 39,
#          'cry': 39,
#          'de': 39,
#          'oars': 39,
#          'table': 38,
#          'forecastle': 38,
#          'cutting': 38,
#          'bulwarks': 38,
#          'leaving': 38,
#          'brought': 38,
#          'fixed': 38,
#          'around': 38,
#          'chief': 38,
#          'sailed': 38,
#          'middle': 38,
#          'ha': 38,
#          'forehead': 38,
#          'darted': 38,
#          'gave': 38,
#          'power': 38,
#          'gentlemen': 38,
#          'start': 37,
#          'wood': 37,
#          'loose': 37,
#          'brain': 37,
#          'placed': 37,
#          'free': 37,
#          'mad': 37,
#          'manner': 37,
#          'shot': 37,
#          'bear': 37,
#          'famous': 37,
#          'suppose': 37,
#          'holding': 37,
#          'lines': 37,
#          'human': 37,
#          'held': 37,
#          'skin': 37,
#          've': 37,
#          'seeing': 37,
#          'flukes': 37,
#          'heavy': 37,
#          'arms': 37,
#          'aspect': 37,
#          'given': 37,
#          'daggoo': 37,
#          'town': 36,
#          'strong': 36,
#          'greenland': 36,
#          'ago': 36,
#          'nearly': 36,
#          'fell': 36,
#          'previous': 36,
#          'legs': 36,
#          'wonder': 36,
#          'sign': 36,
#          'unknown': 36,
#          'truth': 36,
#          'sky': 36,
#          'born': 36,
#          'natural': 36,
#          'rose': 35,
#          'skeleton': 35,
#          'pacific': 35,
#          'rolling': 35,
#          'killed': 35,
#          'boys': 35,
#          'spring': 35,
#          'weather': 35,
#          'hope': 35,
#          'helm': 35,
#          'kill': 34,
#          'third': 34,
#          'creatures': 34,
#          'ashore': 34,
#          'account': 34,
#          'passage': 34,
#          'american': 34,
#          'rigging': 34,
#          'landlord': 34,
#          'fair': 34,
#          'none': 34,
#          'thoughts': 34,
#          'turns': 34,
#          'remained': 34,
#          'twenty': 34,
#          'except': 34,
#          'sailing': 34,
#          'blubber': 34,
#          'terms': 33,
#          'forty': 33,
#          'fifty': 33,
#          'state': 33,
#          'fear': 33,
#          'steel': 33,
#          'island': 33,
#          'unless': 33,
#          'idea': 33,
#          'already': 33,
#          'stop': 33,
#          'foot': 33,
#          'didn': 33,
#          'want': 33,
#          'company': 33,
#          'hammock': 33,
#          'completely': 33,
#          'drawing': 33,
#          'hardly': 33,
#          'ho': 32,
#          'thunder': 32,
#          'strike': 32,
#          'bulk': 32,
#          'doubt': 32,
#          'miles': 32,
#          'fresh': 32,
#          'storm': 32,
#          'darkness': 32,
#          'harpoons': 32,
#          'jet': 32,
#          'visible': 32,
#          'person': 32,
#          'show': 32,
#          'proper': 32,
#          'hence': 32,
#          'aft': 32,
#          'nose': 32,
#          'intervals': 32,
#          'hull': 32,
#          'fin': 32,
#          'supper': 31,
#          'shark': 31,
#          'generally': 31,
#          'six': 31,
#          'received': 31,
#          'battle': 31,
#          'species': 31,
#          'bound': 31,
#          'upper': 31,
#          'considering': 31,
#          'snow': 31,
#          'cold': 31,
#          'tossed': 31,
#          'planks': 31,
#          'knife': 31,
#          'soft': 31,
#          'won': 31,
#          'during': 31,
#          'substance': 31,
#          'cast': 31,
#          'across': 31,
#          'pass': 31,
#          'woe': 31,
#          'instances': 31,
#          'rising': 31,
#          'midnight': 30,
#          'lamp': 30,
#          'late': 30,
#          'swimming': 30,
#          'huge': 30,
#          'jaws': 30,
#          'possible': 30,
#          'possibly': 30,
#          'smoke': 30,
#          'vain': 30,
#          'act': 30,
#          'really': 30,
#          'horn': 30,
#          'flying': 30,
#          'hung': 30,
#          'touch': 30,
#          'read': 30,
#          'carried': 30,
#          'die': 30,
#          'suspended': 30,
#          'hammer': 30,
#          'hoisted': 30,
#          'altogether': 29,
#          'hearts': 29,
#          'hast': 29,
#          'play': 29,
#          'south': 29,
#          'pretty': 29,
#          'entirely': 29,
#          'steady': 29,
#          'astern': 29,
#          'nay': 29,
#          'words': 29,
#          'final': 29,
#          'stands': 29,
#          'mariners': 29,
#          'certainly': 29,
#          'm': 29,
#          'question': 29,
#          'sideways': 29,
#          'pointed': 29,
#          'strangely': 29,
#          'leeward': 29,
#          'pole': 29,
#          'whiteness': 28,
#          'fedallah': 28,
#          'lightning': 28,
#          'coat': 28,
#          'ancient': 28,
#          'royal': 28,
#          'sides': 28,
#          'thirty': 28,
#          'kind': 28,
#          'fishermen': 28,
#          'gale': 28,
#          'leaning': 28,
#          'knows': 28,
#          'mild': 28,
#          'considerable': 28,
#          'meanwhile': 28,
#          'gods': 28,
#          'scene': 28,
#          'number': 28,
#          'shipmates': 28,
#          'become': 28,
#          'feeling': 28,
#          'thinking': 28,
#          'giving': 28,
#          'command': 28,
#          'glance': 28,
#          'hunters': 28,
#          'oar': 28,
#          'foundation': 28,
#          'parsee': 28,
#          'friend': 27,
#          'country': 27,
#          'horse': 27,
#          'eight': 27,
#          'yards': 27,
#          'lie': 27,
#          'year': 27,
#          'tis': 27,
#          'finally': 27,
#          'bit': 27,
#          'precisely': 27,
#          'seated': 27,
#          'believe': 27,
#          'started': 27,
#          'following': 27,
#          'ice': 27,
#          'thick': 27,
#          'wooden': 27,
#          'somewhat': 27,
#          'eyeing': 27,
#          'pilot': 27,
#          'looks': 27,
#          'overboard': 27,
#          'father': 27,
#          'dropped': 27,
#          'wholly': 27,
#          'ahead': 27,
#          'alongside': 27,
#          'cruising': 27,
#          'electronic': 27,
#          'shore': 26,
#          'dart': 26,
#          'talk': 26,
#          'floating': 26,
#          'masts': 26,
#          'carry': 26,
#          'enormous': 26,
#          'vessels': 26,
#          'degree': 26,
#          'silent': 26,
#          'yourself': 26,
#          'drawn': 26,
#          'circumstances': 26,
#          'port': 26,
#          'followed': 26,
#          'ears': 26,
#          'hair': 26,
#          'fancy': 26,
#          'chest': 26,
#          'getting': 26,
#          'otherwise': 26,
#          'war': 26,
#          'takes': 26,
#          'wife': 26,
#          'circumstance': 26,
#          'alive': 26,
#          'sweet': 26,
#          'keel': 26,
#          'bodily': 26,
#          'spread': 26,
#          'according': 26,
#          'blow': 26,
#          'honor': 25,
#          'regarded': 25,
#          'sword': 25,
#          'learned': 25,
#          'seldom': 25,
#          'thrown': 25,
#          'bright': 25,
#          'self': 25,
#          'front': 25,
#          'dutch': 25,
#          'different': 25,
#          'watery': 25,
#          'drop': 25,
#          'answer': 25,
#          'afterwards': 25,
#          'hump': 25,
#          'cases': 25,
#          'added': 25,
#          'interval': 25,
#          'duty': 25,
#          'similar': 25,
#          'skull': 25,
#          'aside': 25,
#          'wise': 25,
#          'beat': 25,
#          'complete': 25,
#          'bearing': 25,
#          'hinted': 25,
#          'warm': 24,
#          'grow': 24,
#          'love': 24,
#          'blows': 24,
#          'striking': 24,
#          'regular': 24,
#          'pursuit': 24,
#          'orders': 24,
#          'captains': 24,
#          'fore': 24,
#          'exactly': 24,
#          'perils': 24,
#          'became': 24,
#          'beyond': 24,
#          'fiery': 24,
#          'wall': 24,
#          'swift': 24,
#          'cause': 24,
#          'ran': 24,
#          'owing': 24,
#          'commanded': 24,
#          'instead': 24,
#          'headed': 24,
#          'lad': 24,
#          'escape': 24,
#          'circle': 24,
#          'strength': 24,
#          'thyself': 24,
#          'remain': 24,
#          'secret': 24,
#          'remains': 24,
#          'hunt': 24,
#          'level': 24,
#          'pulling': 24,
#          'lakeman': 24,
#          'bag': 23,
#          'magnitude': 23,
#          'log': 23,
#          'original': 23,
#          'master': 23,
#          'globe': 23,
#          'ah': 23,
#          'negro': 23,
#          'tall': 23,
#          'spot': 23,
#          'lances': 23,
#          'flew': 23,
#          'higher': 23,
#          'break': 23,
#          'somewhere': 23,
#          'yellow': 23,
#          'hot': 23,
#          'passing': 23,
#          'real': 23,
#          'hidden': 23,
#          'meantime': 23,
#          'pagan': 23,
#          'instantly': 23,
#          'law': 23,
#          'flesh': 23,
#          'burst': 23,
#          'hint': 23,
#          'speaking': 23,
#          'consider': 23,
#          'gazing': 23,
#          'aboard': 22,
#          'blacksmith': 22,
#          'empty': 22,
#          'french': 22,
#          'sing': 22,
#          'answered': 22,
#          'stove': 22,
#          'laid': 22,
#          'lives': 22,
#          'rear': 22,
#          'east': 22,
#          'ain': 22,
#          'formed': 22,
#          'jolly': 22,
#          'sitting': 22,
#          'wonderful': 22,
#          'centre': 22,
#          'filled': 22,
#          'avast': 22,
#          'sleeping': 22,
#          'likewise': 22,
#          'jacket': 22,
#          'terrible': 22,
#          'game': 22,
#          'drew': 22,
#          'deadly': 22,
#          'step': 22,
#          'descried': 22,
#          'souls': 22,
#          'post': 22,
#          'nantucketer': 22,
#          'windward': 22,
#          'seventy': 22,
#          'sink': 22,
#          'dashed': 22,
#          'scuttle': 22,
#          'advance': 22,
#          'golden': 22,
#          'attached': 22,
#          'radney': 22,
#          'lee': 21,
#          'doubloon': 21,
#          'gay': 21,
#          'swim': 21,
#          'holy': 21,
#          'ribs': 21,
#          'history': 21,
#          'directly': 21,
#          'tree': 21,
#          'distant': 21,
#          'winds': 21,
#          'decks': 21,
#          'states': 21,
#          'worse': 21,
#          'repeated': 21,
#          ...})

# %% [markdown]
# # Interesting Part
# # Calculate Word probability
#  first we have to find out t.no of words once again
#
#  1: P(word) = count(word) / N

# %%
total_words_count = float(sum(words_count.values()))

# %%
word_probabs = {word:words_count[word] / total_words_count for word in words_count.keys()}

# %%
word_probabs['the']
# Out:
# 0.06603252448767868

# %% [markdown]
# # Autocorrect operations

# %% [markdown]
# # 1 Split Operation:
#    first split word into two components
#    [('', 'hello'), ('h', 'ello'), ('he', 'llo'), ('hel', 'lo'), ('hell', 'o'), ('hello', '')]

# %%
def split(word): # why
    return [ (word[:i], word[i:])  for i in range(len(word) + 1)]

# %%
print(split('why'))
# Out:
# [('', 'why'), ('w', 'hy'), ('wh', 'y'), ('why', '')]

# %% [markdown]
# # 2 Delete Operation:

# %%
def delete(word):
    return [left + right[1:] for left,right in split(word) if right]

# %%
print(delete('why'))
# Out:
# ['hy', 'wy', 'wh']

# %% [markdown]
# # 3 Swap Operation:

# %%
def swap(word):
    return [left + right[1] + right[0] + right[2:] for left,right in split(word) if len(right) > 1 ]

# %%
print(swap('why')) #hy == yh
# Out:
# ['hwy', 'wyh']

# %% [markdown]
# # 4 replace Operation:
# The string.ascii_lowercase is equivalent to the string "abcdefghijklmnopqrstuvwxyz"

# %%
def replace(word): # abcdef...z
    return [left + center + right[1:] for left, right in split(word) if right for center in string.ascii_lowercase]

# %%
print(replace('why'))
# Out:
# ['ahy', 'bhy', 'chy', 'dhy', 'ehy', 'fhy', 'ghy', 'hhy', 'ihy', 'jhy', 'khy', 'lhy', 'mhy', 'nhy', 'ohy', 'phy', 'qhy', 'rhy', 'shy', 'thy', 'uhy', 'vhy', 'why', 'xhy', 'yhy', 'zhy', 'way', 'wby', 'wcy', 'wdy', 'wey', 'wfy', 'wgy', 'why', 'wiy', 'wjy', 'wky', 'wly', 'wmy', 'wny', 'woy', 'wpy', 'wqy', 'wry', 'wsy', 'wty', 'wuy', 'wvy', 'wwy', 'wxy', 'wyy', 'wzy', 'wha', 'whb', 'whc', 'whd', 'whe', 'whf', 'whg', 'whh', 'whi', 'whj', 'whk', 'whl', 'whm', 'whn', 'who', 'whp', 'whq', 'whr', 'whs', 'wht', 'whu', 'whv', 'whw', 'whx', 'why', 'whz']

# %% [markdown]
# # 5 Insert Opearations

# %%
def insert(word): # abcdef...z
    return [left + center + right[1:] for left, right in split(word) for center in string.ascii_lowercase]

# %%
print(replace('love'))
# Out:
# ['aove', 'bove', 'cove', 'dove', 'eove', 'fove', 'gove', 'hove', 'iove', 'jove', 'kove', 'love', 'move', 'nove', 'oove', 'pove', 'qove', 'rove', 'sove', 'tove', 'uove', 'vove', 'wove', 'xove', 'yove', 'zove', 'lave', 'lbve', 'lcve', 'ldve', 'leve', 'lfve', 'lgve', 'lhve', 'live', 'ljve', 'lkve', 'llve', 'lmve', 'lnve', 'love', 'lpve', 'lqve', 'lrve', 'lsve', 'ltve', 'luve', 'lvve', 'lwve', 'lxve', 'lyve', 'lzve', 'loae', 'lobe', 'loce', 'lode', 'loee', 'lofe', 'loge', 'lohe', 'loie', 'loje', 'loke', 'lole', 'lome', 'lone', 'looe', 'lope', 'loqe', 'lore', 'lose', 'lote', 'loue', 'love', 'lowe', 'loxe', 'loye', 'loze', 'lova', 'lovb', 'lovc', 'lovd', 'love', 'lovf', 'lovg', 'lovh', 'lovi', 'lovj', 'lovk', 'lovl', 'lovm', 'lovn', 'lovo', 'lovp', 'lovq', 'lovr', 'lovs', 'lovt', 'lovu', 'lovv', 'lovw', 'lovx', 'lovy', 'lovz']

# %% [markdown]
# # find minimum distance
# five edit for misspelled word or candidates
#
# The "level_one_edits" function in this code snippet is a Python function that takes a single argument "word". The purpose of this function is to generate a set of all possible "candidate" words that can be obtained by applying four types of "edit" operations to the input "word". These operations are:
#
# Delete: Remove one character from the input word
# Swap: Swap adjacent pairs of characters in the input word
# Replace: Replace one character in the input word with a different lowercase letter
# Insert: Insert one lowercase letter at any position in the input word

# %%
def level_one_edits(word):
    return set((delete(word) + swap(word) + replace(word) + insert(word)))

# %%
print(level_one_edits('load'))
# Out:
# {'lfad', 'lotd', 'loade', 'zoad', 'loav', 'loadr', 'lbad', 'lovd', 'loae', 'lopd', 'lkad', 'loaz', 'boad', 'lpad', 'loadf', 'voad', 'loadg', 'loadi', 'lsad', 'yoad', 'ioad', 'oad', 'loat', 'loaj', 'lqad', 'loai', 'lead', 'lrad', 'joad', 'loadl', 'loxd', 'loan', 'load', 'noad', 'loadk', 'eoad', 'lodd', 'loado', 'loau', 'lvad', 'loaa', 'lojd', 'loao', 'loaw', 'loyd', 'lohd', 'lobd', 'losd', 'loaf', 'loadq', 'loam', 'lozd', 'coad', 'loac', 'lowd', 'road', 'loak', 'loal', 'lcad', 'ljad', 'loag', 'loady', 'koad', 'llad', 'loqd', 'soad', 'loadp', 'qoad', 'lgad', 'loadv', 'laad', 'logd', 'loadn', 'loadb', 'lofd', 'lood', 'lod', 'loab', 'loadd', 'loada', 'xoad', 'lnad', 'loadc', 'foad', 'loadz', 'hoad', 'lad', 'lond', 'loda', 'locd', 'moad', 'uoad', 'goad', 'loax', 'liad', 'lhad', 'loa', 'lwad', 'loud', 'lzad', 'lord', 'loadm', 'loaq', 'loadh', 'ltad', 'lomd', 'luad', 'toad', 'lxad', 'loadj', 'poad', 'loap', 'loed', 'lold', 'laod', 'loah', 'loay', 'aoad', 'ooad', 'doad', 'lyad', 'loar', 'ldad', 'loadx', 'lmad', 'olad', 'loas', 'loads', 'woad', 'loadw', 'loadt', 'loadu', 'loid', 'lokd'}

# %% [markdown]
# # Gets all cands that we want to find out

# %%
def level_two_edits(word):
    return set(e2  for e1 in level_one_edits(word) for e2 in level_one_edits(e1))

# %%
print(level_two_edits('cut'))
# Out:
# {'nyt', 'chtv', 'kft', 'cte', 'cutz', 'jutl', 'cytp', 'vuj', 'sutj', 'ngt', 'cytv', 'int', 'cutoi', 'cutcw', 'utu', 'uctu', 'kut', 'ouo', 'cztq', 'wct', 'cutp', 'cga', 'xuc', 'cuci', 'cpj', 'cuss', 'ccd', 'cmo', 'ast', 'vuu', 'cuns', 'cusd', 'ucc', 'lutj', 'juh', 'cpti', 'zutn', 'cjtm', 'wrt', 'jui', 'nt', 'muc', 'ctum', 'xuti', 'wuj', 'cutzz', 'kutl', 'yuq', 'uutc', 'catb', 'cugv', 'ctv', 'qui', 'qud', 'kuk', 'atu', 'catg', 'cuqa', 'cuxj', 'vutq', 'tutp', 'czi', 'ctp', 'chte', 'cuua', 'lutt', 'cvj', 'ctj', 'gutn', 'cqto', 'cutgr', 'cutqr', 'vuts', 'coh', 'cjtp', 'cunx', 'cutsq', 'cwtd', 'cgty', 'cuttx', 'cutkq', 'cvm', 'mug', 'ytt', 'putm', 'us', 'cee', 'cutig', 'hutz', 'cwa', 'lutc', 'cktf', 'dwt', 'cutis', 'kutn', 'cucg', 'putk', 'xutn', 'cwty', 'cltb', 'cutfm', 'cr', 'cft', 'cume', 'cunl', 'cutre', 'cuno', 'cuhx', 'cgj', 'fbt', 'cutav', 'cuvj', 'rutn', 'cuxg', 'cutoj', 'cutrd', 'kuv', 'cuwn', 'crp', 'fnt', 'cew', 'rux', 'yutb', 'auts', 'clto', 'cutnk', 'cmtz', 'wtu', 'cuttk', 'zuc', 'cuvb', 'eutp', 'cutdr', 'cctb', 'fht', 'cntv', 'cutym', 'gtt', 'iutp', 'cuof', 'cutpj', 'cuttf', 'guth', 'ybt', 'xuy', 'kyt', 'cij', 'pvt', 'ctuj', 'kutb', 'cutsv', 'duts', 'cdti', 'cuaq', 'bdt', 'jutx', 'uuto', 'vue', 'cjd', 'cje', 'cutfw', 'ui', 'putq', 'cytm', 'outc', 'uk', 'vft', 'cutfv', 'csu', 'cntw', 'aut', 'cuxm', 'guu', 'curo', 'auu', 'cdd', 'cutid', 'lpt', 'ywt', 'cki', 'cumx', 'cftk', 'cu', 'cuk', 'cutzi', 'crtl', 'cfw', 'cutbr', 'auti', 'cky', 'ckl', 'cxe', 'cutcz', 'cueb', 'cdq', 'cxtz', 'hul', 'sot', 'eit', 'cua', 'cubl', 'cvtt', 'cuvn', 'cubi', 'cuqu', 'cutou', 'cuttd', 'cfty', 'c', 'ruk', 'cgs', 'euk', 'cutcx', 'xuo', 'cutwv', 'cvte', 'cgto', 'cok', 'wzt', 'cuun', 'czq', 'cltf', 'jup', 'uuo', 'cutpr', 'ucl', 'urt', 'lut', 'vjt', 'crn', 'cutoz', 'net', 'cuot', 'qnt', 'tit', 'cmw', 'futb', 'vum', 'hyt', 'ruv', 'cuve', 'cuvw', 'uctp', 'et', 'hutt', 'ect', 'luj', 'aot', 'pgt', 'cuiz', 'tat', 'iug', 'cxy', 'cxz', 'cgtw', 'cdj', 'ctue', 'xute', 'lutg', 'lutb', 'cutza', 'cutgs', 'cutlp', 'cxtv', 'cuthg', 'cuji', 'cbta', 'wub', 'cnto', 'un', 'cytf', 'cutik', 'cura', 'cutlf', 'cutds', 'caz', 'butw', 'cutrx', 'set', 'cuws', 'ceti', 'juj', 'wutn', 'crtx', 'cmtp', 'nutp', 'buq', 'lutx', 'ccte', 'cuteu', 'ozt', 'cutyc', 'ypt', 'cwg', 'cutuj', 'cutmi', 'cutxx', 'hdt', 'cutgn', 'cuuw', 'cutox', 'fjt', 'cutkf', 'cztn', 'ott', 'cuvp', 'citl', 'jht', 'vux', 'rvt', 'cusp', 'cwm', 'cugh', 'eqt', 'cutce', 'wutk', 'xup', 'cxtm', 'xuth', 'iuq', 'cuob', 'cukf', 'cutiw', 'cufy', 'cutkb', 'cttg', 'gutx', 'cjtv', 'cutw', 'butj', 'cutm', 'cust', 'cutsy', 'cuzz', 'cutip', 'yuv', 'cutqt', 'ltt', 'tkt', 'cupy', 'putp', 'cupl', 'cutxs', 'outu', 'cujs', 'cutvj', 'cusg', 'eug', 'uuf', 'vmt', 'crk', 'cuxh', 'cutnb', 'yutj', 'cca', 'yutx', 'dgt', 'cdte', 'cnta', 'cmtn', 'cue', 'chto', 'cm', 'kutm', 'amt', 'rct', 'cutpq', 'hui', 'cnq', 'ch', 'putg', 'qqt', 'pit', 'cutom', 'cugz', 'wur', 'dutf', 'tet', 'hzt', 'vuv', 'eutl', 'cuuz', 'cutax', 'cltp', 'tutb', 'cfb', 'dutx', 'cutjb', 'ctn', 'cugy', 'cgtk', 'crtq', 'hwt', 'cftl', 'chv', 'cutah', 'cuttb', 'cly', 'cqtk', 'iqt', 'hutb', 'cvtm', 'cuoj', 'tt', 'duth', 'uute', 'cutyv', 'cjto', 'cuzb', 'juto', 'okt', 'cwx', 'cfq', 'mun', 'cutvd', 'cyts', 'cvc', 'fmt', 'auv', 'cuyf', 'sst', 'duy', 'cotm', 'cuthe', 'cxtx', 'cutcu', 'cutgw', 'cmb', 'muty', 'chk', 'cctn', 'cqx', 'dul', 'czv', 'cutbh', 'cmto', 'cta', 'cukk', 'sux', 'fuk', 'wutc', 'cutxh', 'qus', 'wuh', 'cqtn', 'cutup', 'cutwh', 'yutp', 'xxt', 'muto', 'cjv', 'cuhf', 'cwti', 'cstt', 'cbth', 'cueq', 'dup', 'buto', 'cutqo', 'cutxy', 'ruj', 'cufn', 'cdts', 'cutbl', 'cyr', 'egt', 'ygt', 'cwtx', 'cutts', 'rtt', 'cuez', 'culw', 'iuti', 'cgf', 'wit', 'cetd', 'eui', 'oub', 'cutoy', 'cctv', 'cnf', 'uutz', 'cuyv', 'ctuv', 'pun', 'cutgo', 'cujb', 'wdt', 'tutu', 'cqu', 'utm', 'jutp', 'cwtf', 'wun', 'cuiv', 'cco', 'cutvt', 'futm', 'caf', 'cate', 'uutv', 'cuttp', 'cgn', 'cutix', 'futt', 'aun', 'hst', 'cttf', 'cuyz', 'smt', 'iuz', 'xus', 'cuvm', 'cuzm', 'cwj', 'nuj', 'chh', 'cuxb', ...

# %% [markdown]
# # Autocorrect Search Bar

# %%
def correct_spelling(word,vocab,word_probabs):
    if word in vocab:
        print(f"{word} is already correctly spelled")
        return 
    #getting all suggesions
    suggestions = level_one_edits(word) or level_two_edits(word) or [word]
    best_guesses = [w for w in suggestions if w in vocab]
    return [(w, word_probabs[w]) for w in best_guesses]

# %%
search_word = "laed"
guess = correct_spelling(search_word,vocab,word_probabs)
print(guess)
# Out:
# [('laid', 9.880402222192281e-05), ('led', 4.4910919191783095e-05), ('lead', 8.083965454520958e-05), ('land', 0.00035928735353426476), ('lard', 1.347327575753493e-05), ('lad', 0.00010778620606027944)]
